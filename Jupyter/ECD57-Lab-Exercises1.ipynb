# %% [markdown]
# # Swift is better than Python IMO

# %% [markdown]
# * Ethan Defilippi
# * August 31, 2022

# %% [markdown]
# ## Markdown Exercises

# %% [markdown]
# I'm interested in learning code for a meriad of reasons. However, my *main* reason for learning to code is very simple. It's **MONEY**. I really like money. I hope that being able to program will help me earn a lot of money. Some things I would like to learn from the SCI or Pitt in general are:
#
# * How to make tons of money in CS
# * How to code Swift better
# * Why does Pitt keep nickle and diming me
# * Simple Python coding
# * Where does all my money go when I pay Pitt a massive amount each year

# %% [markdown]
# ![Me rn](https://media.giphy.com/media/bE3gZlyt8NdGZxt1E4/giphy.gif "bruh")

# %% [markdown]
# ---

# %% [markdown]
# ## Jupyter Notebook Exercises

# %%
name= input(prompt="What is your name? ")
print("Hello", name, "!")
# Out:
# What is your name?  Ethan
# Hello Ethan !

# %% [markdown]
# When I ran the code, in the output, the question "What is your name?" appeared. Directly next to the question was an input field that I could type my name into. I typed my name in, and it printed out "Hello Ethan !" in the output.

# %%
name= input(prompt="What is your name?" )
color= input(prompt="What is your favorite color?")
q = input(prompt="Do you like Pitt so far?")
q = "NO"
print("Hello", name)
print("Your favorite color is: ", color)
print("Do you like Pitt? ", q)
# Out:
# What is your name? Ethan
# What is your favorite color? Blue
# Do you like Pitt so far? Sure
# Hello Ethan
# Your favorite color is:  Blue
# Do you like Pitt?  NO

# %% [markdown]
# I modified the original amount of user-input prompts that were asked. I also overrided a user input that was inputted. My code ran successfully.

# %%
# %matplotlib inline
import pandas as pd
# Load the PGH 311 Complaint data
data_url = \
"https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4"
complaints = pd.read_csv(data_url, parse_dates=True, index_col="CREATED_ON")
# Produce a graph that shows the number of complaints per month
complaints.resample("M").size().plot();

# %% [markdown]
# The code that I executed above produced a graph as an output. The data in the chart seems to tell us the number of complaints about something per month per year. This assumption is based upon some comments within the code.

# %% [markdown]
# ![Me rn](https://media.giphy.com/media/bE3gZlyt8NdGZxt1E4/giphy.gif "bruh")
